# %%
# %pip install -U pandas numpy scikit-learn xgboost catboost lightgbm torch optuna joblib

# %% [markdown]
# ## 0)Environment configuration and necessary library imports

# %%
import os, json, math, warnings, gc, time
from typing import Dict, List, Optional, Tuple
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, GroupKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor  
from sklearn.base import clone
warnings.filterwarnings("ignore")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import optuna

# %% [markdown]
# ## 1)Tool Functions: Metrics Evaluation and Data Processing

# %%
def _rmse(y_true, y_pred) -> float:
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def _to_arr(a):
    if isinstance(a, (pd.DataFrame, pd.Series)):
        return a.to_numpy()
    return np.asarray(a)

def _make_dir(p):
    os.makedirs(p, exist_ok=True)

# %% [markdown]
# ## 2)GPU and PyTorch device detection

# %%
# Check if GPU is available (using CUDA)
def _gpu_available() -> bool:
    import shutil, os
    try:
        import torch
        if torch.cuda.is_available():
            return True
    except Exception:
        pass
    try:
        import cupy
        if cupy.cuda.runtime.getDeviceCount() > 0:
            return True
    except Exception:
        pass
    if shutil.which("nvidia-smi"):
        return True
    if os.environ.get("CUDA_VISIBLE_DEVICES", "") not in ("", "-1", None):
        return True
    return False

# Check if PyTorch is installed and available
def _torch_ok() -> bool:
    try:
        import torch
        return True
    except Exception:
        return False

# Set device (GPU or CPU) for PyTorch
def _torch_device():
    try:
        import torch
        return torch.device("cuda" if torch.cuda.is_available() else "cpu")
    except Exception:
        return None

# %% [markdown]
# ## 3)Set all random seeds for reproducibility across libraries

# %%
def _set_all_seeds(seed: int = 42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    try:
        import torch
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    except Exception:
        pass

# %% [markdown]
# ## 4)MLP Model Construction and Training (PyTorch Implementation)

# %%
# Create a simple MLP model using PyTorch
def _make_mlp(in_dim: int, out_dim: int, width: int, nlayer: int, dropout: float):
    import torch.nn as nn
    layers = []
    last = in_dim
    act = nn.ReLU()
    for _ in range(nlayer):
        layers += [nn.Linear(last, width), act, nn.Dropout(dropout)]
        last = width
    layers += [nn.Linear(last, out_dim)]
    return nn.Sequential(*layers)

# Training one epoch for the MLP model
def _train_one_epoch(model, loader, criterion, optimizer, device):
    import torch
    model.train()
    loss_sum, n = 0.0, 0
    for xb, yb in loader:
        xb = xb.to(device); yb = yb.to(device)
        optimizer.zero_grad(set_to_none=True)
        pred = model(xb).squeeze(-1)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        bs = yb.size(0)
        loss_sum += loss.item() * bs
        n += bs
    return loss_sum / max(1, n)

# Evaluate RMSE on validation set for the model
def _eval_rmse(model, loader, device):
    import torch
    model.eval()
    se_sum, n = 0.0, 0
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device); yb = yb.to(device)
            pred = model(xb).squeeze(-1)
            se_sum += torch.sum((pred - yb) ** 2).item()
            n += yb.size(0)
    return _safe_sqrt(se_sum / max(1, n))

# %% [markdown]
# ## 5)PyTorch Model Training: Data Standardisation and Model Optimisation

# %%
# Fit MLP using PyTorch with standardization and hyperparameter tuning
def _fit_torch_mlp(
    X_tr, y_tr, X_va, y_va,
    width: int, nlayer: int, dropout: float,
    lr: float, weight_decay: float,
    batch: int, epochs: int, patience: int,
    seed: int = 42, verbose: bool = False
):
    import torch
    import torch.nn as nn
    from torch.utils.data import TensorDataset, DataLoader

    # Standardize the data
    scaler = StandardScaler(with_mean=True, with_std=True)
    X_tr_std = scaler.fit_transform(X_tr)
    X_va_std = scaler.transform(X_va)

    # Convert to PyTorch tensors
    Xtr = torch.tensor(X_tr_std, dtype=torch.float32)
    ytr = torch.tensor(y_tr.reshape(-1), dtype=torch.float32)
    Xva = torch.tensor(X_va_std, dtype=torch.float32)
    yva = torch.tensor(y_va.reshape(-1), dtype=torch.float32)

    _set_all_seeds(seed)
    device = _torch_device() or "cpu"

    # DataLoader for training and validation
    train_loader = DataLoader(TensorDataset(Xtr, ytr), batch_size=int(batch), shuffle=True)
    val_loader   = DataLoader(TensorDataset(Xva, yva), batch_size=4096, shuffle=False)

    # MLP network architecture
    net = _make_mlp(in_dim=X_tr.shape[1], out_dim=1, width=int(width), nlayer=int(nlayer), dropout=float(dropout)).to(device)
    optimizer = torch.optim.AdamW(net.parameters(), lr=float(lr), weight_decay=float(weight_decay))
    criterion = nn.MSELoss()

    best_rmse = float("inf")
    best_state = None
    wait = 0

    # Training loop
    for ep in range(int(epochs)):
        _ = _train_one_epoch(net, train_loader, criterion, optimizer, device)
        rmse = _eval_rmse(net, val_loader, device)
        if verbose and (ep % 10 == 0 or ep == epochs - 1):
            print(f"[Torch-MLP] epoch {ep:03d}  val RMSE={rmse:.5f}")

        if rmse + 1e-6 < best_rmse:
            best_rmse = rmse
            best_state = {k: v.detach().cpu().clone() for k, v in net.state_dict().items()}
            wait = 0
        else:
            wait += 1
            if wait >= int(patience):
                break

    del Xtr, ytr, Xva, yva
    try:
        torch.cuda.empty_cache()
    except Exception:
        pass

    return scaler, best_state, best_rmse

def _fit_torch_mlp(
    X_tr, y_tr, X_va, y_va,
    width: int, nlayer: int, dropout: float,
    lr: float, weight_decay: float,
    batch: int, epochs: int, patience: int,
    seed: int = 42, verbose: bool = False
):
    import torch
    import torch.nn as nn
    from torch.utils.data import TensorDataset, DataLoader

    scaler = StandardScaler(with_mean=True, with_std=True)
    X_tr_std = scaler.fit_transform(X_tr)
    X_va_std = scaler.transform(X_va)

    Xtr = torch.tensor(X_tr_std, dtype=torch.float32)
    ytr = torch.tensor(y_tr.reshape(-1), dtype=torch.float32)
    Xva = torch.tensor(X_va_std, dtype=torch.float32)
    yva = torch.tensor(y_va.reshape(-1), dtype=torch.float32)

    _set_all_seeds(seed)
    device = _torch_device() or "cpu"

    train_loader = DataLoader(TensorDataset(Xtr, ytr), batch_size=int(batch), shuffle=True)
    val_loader   = DataLoader(TensorDataset(Xva, yva), batch_size=4096, shuffle=False)

    net = _make_mlp(in_dim=X_tr.shape[1], out_dim=1, width=int(width), nlayer=int(nlayer), dropout=float(dropout)).to(device)
    optimizer = torch.optim.AdamW(net.parameters(), lr=float(lr), weight_decay=float(weight_decay))
    criterion = nn.MSELoss()

    best_rmse = float("inf")
    best_state = None
    wait = 0

    for ep in range(int(epochs)):
        _ = _train_one_epoch(net, train_loader, criterion, optimizer, device)
        rmse = _eval_rmse(net, val_loader, device)
        if verbose and (ep % 10 == 0 or ep == epochs - 1):
            print(f"[Torch-MLP] epoch {ep:03d}  val RMSE={rmse:.5f}")

        if rmse + 1e-6 < best_rmse:
            best_rmse = rmse
            best_state = {k: v.detach().cpu().clone() for k, v in net.state_dict().items()}
            wait = 0
        else:
            wait += 1
            if wait >= int(patience):
                break

    
    del Xtr, ytr, Xva, yva
    try:
        torch.cuda.empty_cache()
    except Exception:
        pass

    return scaler, best_state, best_rmse

class TorchMLPRegressor:
    def __init__(self, **params):
        self.params = dict(params)
        self.scaler_ = None
        self.state_  = None
        self.in_dim_ = None

    def fit(self, X, y):
        if not _torch_ok():
            raise RuntimeError("PyTorch is not available.")
        n = len(y); m = max(1, int(0.1 * n))
        X_tr, y_tr = X[m:], y[m:]
        X_va, y_va = X[:m], y[:m]
        self.in_dim_ = X.shape[1]
        self.scaler_, self.state_, _ = _fit_torch_mlp(
            X_tr, y_tr, X_va, y_va,
            self.params["width"], self.params["nlayer"], self.params["dropout"],
            self.params["lr"], self.params["weight_decay"],
            self.params["batch"], self.params["epochs"], self.params["patience"],
            seed=42, verbose=False
        )
        return self

    def predict(self, X):
        if not _torch_ok():
            raise RuntimeError("PyTorch is not available.")
        import torch
        if self.state_ is None or self.scaler_ is None:
            raise RuntimeError("Model not fitted yet.")
        X_std = self.scaler_.transform(X)
        X_te = torch.tensor(X_std, dtype=torch.float32)
        device = _torch_device() or "cpu"
        net = _make_mlp(self.in_dim_, 1,
                        width=self.params["width"],
                        nlayer=self.params["nlayer"],
                        dropout=self.params["dropout"]).to(device)
        net.load_state_dict(self.state_)
        net.eval()
        with torch.no_grad():
            yhat = net(X_te.to(device)).cpu().numpy().reshape(-1)
        return yhat

# %% [markdown]
# ## 6)Optuna optimisation: performing hyperparameter tuning for various models

# %%
def obj_xgb(X_tr, y_tr, X_va, y_va):
    def _obj(trial: optuna.Trial):
        params = dict(
            max_depth=trial.suggest_int("max_depth", 6, 14),
            eta=trial.suggest_float("eta", 0.01, 0.2, log=True),
            min_child_weight=trial.suggest_float("min_child_weight", 1.0, 12.0),
            subsample=trial.suggest_float("subsample", 0.6, 1.0),
            colsample_bytree=trial.suggest_float("colsample_bytree", 0.6, 1.0),
            _lambda=trial.suggest_float("lambda", 1e-4, 10.0, log=True),
            alpha=trial.suggest_float("alpha", 1e-6, 1.0, log=True),
        )
        mdl = XGBRegressor(
            max_depth=params["max_depth"],
            learning_rate=params["eta"],
            min_child_weight=params["min_child_weight"],
            subsample=params["subsample"],
            colsample_bytree=params["colsample_bytree"],
            reg_lambda=params["_lambda"],
            reg_alpha=params["alpha"],
            n_estimators=1200,
            tree_method="hist",
            random_state=42,
            n_jobs=-1
        )
        mdl.fit(X_tr, y_tr)
        pred = mdl.predict(X_va)
        return _rmse(y_va, pred)
    return _obj

# %%
def obj_lgb(X_tr, y_tr, X_va, y_va):
    def _obj(trial: optuna.Trial):
        params = dict(
            learning_rate   = trial.suggest_float("learning_rate", 0.01, 0.10, log=True),
            num_leaves      = trial.suggest_int("num_leaves", 64, 512, step=32),
            min_data_in_leaf= trial.suggest_int("min_data_in_leaf", 20, 200, step=10),
            feature_fraction= trial.suggest_float("feature_fraction", 0.6, 1.0),
            bagging_fraction= trial.suggest_float("bagging_fraction", 0.6, 1.0),
            lambda_l1       = trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
            lambda_l2       = trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        )
        mdl = LGBMRegressor(
            **params,
            n_estimators=2000,
            random_state=42,
            n_jobs=-1,
            force_col_wise=True,
            verbosity=-1
        )
        mdl.fit(X_tr, y_tr)
        pred = mdl.predict(X_va)
        return _rmse(y_va, pred)
    return _obj

# %%
def obj_cat(X_tr, y_tr, X_va, y_va):
    def _obj(trial: optuna.Trial):
        params = dict(
            depth=trial.suggest_int("depth", 6, 10),
            learning_rate=trial.suggest_float("learning_rate", 0.02, 0.2, log=True),
            l2_leaf_reg=trial.suggest_float("l2_leaf_reg", 1e-3, 20.0, log=True),
            subsample=trial.suggest_float("subsample", 0.6, 1.0),
        )
        mdl = CatBoostRegressor(
            **params, iterations=2000, loss_function="RMSE",
            random_seed=42, verbose=False
        )
        mdl.fit(X_tr, y_tr)
        pred = mdl.predict(X_va)
        return _rmse(y_va, pred)
    return _obj

# %%
def obj_mlp_torch(X_tr, y_tr, X_va, y_va):
    def _objective(trial: optuna.Trial):
        width        = trial.suggest_categorical("width",  [128, 256, 384, 512, 768, 1024])
        nlayer       = trial.suggest_int("nlayer", 2, 4)
        dropout      = trial.suggest_float("dropout", 0.0, 0.30)
        lr           = trial.suggest_float("lr", 1e-4, 5e-3, log=True)
        weight_decay = trial.suggest_float("weight_decay", 1e-6, 5e-4, log=True)
        batch        = trial.suggest_categorical("batch", [2048, 4096, 8192, 16384])
        epochs       = trial.suggest_int("epochs", 120, 320, step=40)
        patience     = trial.suggest_int("patience", 10, 35)

        if not _torch_ok():
            hidden = tuple([int(width)] * int(nlayer))
            mdl = Pipeline([
                ("scaler", StandardScaler()),
                ("mdl", MLPRegressor(
                    hidden_layer_sizes=hidden, activation="relu",
                    alpha=float(weight_decay),               
                    learning_rate_init=float(lr),
                    batch_size=int(batch),
                    max_iter=int(epochs),
                    early_stopping=True, n_iter_no_change=int(patience),
                    random_state=42))
            ])
            mdl.fit(X_tr, y_tr)
            pred = mdl.predict(X_va)
            return _rmse(y_va, pred)
        try:
            _, _, rmse = _fit_torch_mlp(
                X_tr, y_tr, X_va, y_va,
                width, nlayer, dropout, lr, weight_decay, batch, epochs, patience,
                seed=42, verbose=False
            )
        except Exception:
            rmse = float("inf")
        return rmse
    return _objective

# %% [markdown]
# ## 7)Model Training and Results Documentation

# %%
def run_one_dataset(
    X, y, X_std=None,
    groups: Optional[np.ndarray] = None,
    region_tag: Optional[str] = None,
    n_repeats: int = 1,
    xgb_trials: int = 40,
    cat_trials: int = 40,
    lgb_trials: int = 40,
    mlp_trials: int = 20,
    save_dir: str = "./runs"
) -> Tuple[pd.DataFrame, Dict[str, dict]]:

    GPU_OK = _gpu_available()
    _make_dir(save_dir)
    X = _to_arr(X); y = _to_arr(y).reshape(-1).astype(float)
    n = len(y)

    records: List[dict] = []
    best_param_dict: Dict[str, dict] = {}

    def with_device_params(model_name: str, params: dict, prefer_gpu: bool = True) -> dict:
        p = dict(params)
        if not prefer_gpu:
            return p
        if model_name == "xgboost":
            p["tree_method"] = "gpu_hist" if GPU_OK else p.get("tree_method", "hist")
        elif model_name == "lightgbm":
            if GPU_OK:
                p["device"] = "gpu"
        elif model_name == "catboost":
            if GPU_OK:
                p["task_type"] = "GPU"
                p.setdefault("devices", "0")
        return p

    def _tune_once_on_fold(X_tr, y_tr, X_va, y_va) -> Dict[str, dict]:
        out: Dict[str, dict] = {}

        # XGB
        study = optuna.create_study(direction="minimize",
                                    sampler=optuna.samplers.TPESampler(seed=42),
                                    study_name="xgb_study")
        study.optimize(obj_xgb(X_tr, y_tr, X_va, y_va), n_trials=xgb_trials, show_progress_bar=False)
        bp = dict(study.best_trial.params)
        xgb_best = {
            "max_depth":        int(bp["max_depth"]),
            "learning_rate":    float(bp["eta"]),
            "min_child_weight": float(bp["min_child_weight"]),
            "subsample":        float(bp["subsample"]),
            "colsample_bytree": float(bp["colsample_bytree"]),
            "reg_lambda":       float(bp["lambda"]),
            "reg_alpha":        float(bp["alpha"]),
            "n_estimators":     1200,
            "tree_method":      "hist",
            "random_state":     42,
        }
        out["xgboost"] = {"params": xgb_best, "rmse": float(study.best_trial.value)}

        # Cat
        study = optuna.create_study(direction="minimize",
                                    sampler=optuna.samplers.TPESampler(seed=42),
                                    study_name="cat_study")
        study.optimize(obj_cat(X_tr, y_tr, X_va, y_va), n_trials=cat_trials, show_progress_bar=False)
        bp = dict(study.best_trial.params)
        cat_best = {
            "depth":         int(bp["depth"]),
            "learning_rate": float(bp["learning_rate"]),
            "l2_leaf_reg":   float(bp["l2_leaf_reg"]),
            "subsample":     float(bp["subsample"]),
            "iterations":    2000,
            "loss_function": "RMSE",
            "random_seed":   42,
            "verbose":       False,
        }
        out["catboost"] = {"params": cat_best, "rmse": float(study.best_trial.value)}

        # LGBM
        study = optuna.create_study(direction="minimize",
                                    sampler=optuna.samplers.TPESampler(seed=42),
                                    study_name="lgbm_study")
        study.optimize(obj_lgb(X_tr, y_tr, X_va, y_va), n_trials=lgb_trials, show_progress_bar=False)
        bp = dict(study.best_trial.params)
        lgb_best = {
            "learning_rate":    float(bp["learning_rate"]),
            "num_leaves":       int(bp["num_leaves"]),
            "min_data_in_leaf": int(bp["min_data_in_leaf"]),
            "feature_fraction": float(bp["feature_fraction"]),
            "bagging_fraction": float(bp["bagging_fraction"]),
            "lambda_l1":        float(bp["lambda_l1"]),
            "lambda_l2":        float(bp["lambda_l2"]),
            "n_estimators":     2000,
            "random_state":     42,
            "force_col_wise":   True,
            "verbosity":        -1,
        }
        out["lightgbm"] = {"params": lgb_best, "rmse": float(study.best_trial.value)}

        study = optuna.create_study(direction="minimize",
                                    sampler=optuna.samplers.TPESampler(seed=42),
                                    study_name="mlp_study")
        study.optimize(obj_mlp_torch(X_tr, y_tr, X_va, y_va), n_trials=mlp_trials, show_progress_bar=False)
        bp = dict(study.best_trial.params)

        if _torch_ok():
            mlp_best = {
                "width":         int(bp["width"]),
                "nlayer":        int(bp["nlayer"]),
                "dropout":       float(bp.get("dropout", 0.0)),
                "lr":            float(bp["lr"]),
                "weight_decay":  float(bp.get("weight_decay", 1e-5)),
                "batch":         int(bp["batch"]),
                "epochs":        int(bp["epochs"]),
                "patience":      int(bp["patience"]),
            }
        else:
            hidden = tuple([int(bp["width"])] * int(bp["nlayer"]))
            mlp_best = {
                "hidden_layer_sizes": hidden,
                "alpha":              float(bp.get("weight_decay", 1e-5)),  
                "learning_rate_init": float(bp["lr"]),
                "batch_size":         int(bp["batch"]),
                "max_iter":           int(bp["epochs"]),
                "early_stopping":     True,
                "n_iter_no_change":   int(bp["patience"]),
                "random_state":       42,
                "_backend":           "sklearn",
            }
        out["mlp"] = {"params": mlp_best, "rmse": float(study.best_trial.value)}
        return out

    def _run_scenario(name: str, splitter):
        nonlocal best_param_dict
        tuned = False

        for rep in range(n_repeats):
            iterator = splitter.split(X, y, groups if name == "without_supervision" else None)
            for fold_id, (tr_idx, va_idx) in enumerate(iterator):
                X_tr, y_tr = X[tr_idx], y[tr_idx]
                X_va, y_va = X[va_idx], y[va_idx]

                if not tuned:
                    best_param_dict = _tune_once_on_fold(X_tr, y_tr, X_va, y_va)
                    tuned = True

                xgb_params = with_device_params("xgboost",  best_param_dict["xgboost"]["params"])
                cat_params = with_device_params("catboost", best_param_dict["catboost"]["params"])
                lgb_params = with_device_params("lightgbm", best_param_dict["lightgbm"]["params"])

                if _torch_ok() and "_backend" not in best_param_dict["mlp"]["params"]:
                    mlp_model = TorchMLPRegressor(**best_param_dict["mlp"]["params"])
                else:
                    mlp_model = Pipeline([("scaler", StandardScaler()),
                                          ("mdl", MLPRegressor(**{k: v for k, v in best_param_dict["mlp"]["params"].items()
                                                                  if k != "_backend"}))])

                models = {
                    "xgboost":  XGBRegressor(**xgb_params),
                    "catboost": CatBoostRegressor(**cat_params),
                    "lightgbm": LGBMRegressor(**lgb_params),
                    "mlp":      mlp_model,
                }

                for mname, mdl in models.items():
                    try:
                        mdl.fit(X_tr, y_tr)
                    except Exception:
                        if mname == "xgboost":
                            cpu = dict(xgb_params); cpu["tree_method"] = "hist"
                            mdl = XGBRegressor(**cpu)
                        elif mname == "lightgbm":
                            cpu = dict(lgb_params); cpu.pop("device", None)
                            mdl = LGBMRegressor(**cpu)
                        elif mname == "catboost":
                            cpu = dict(cat_params); cpu.pop("task_type", None); cpu.pop("devices", None)
                            mdl = CatBoostRegressor(**cpu)
                        elif mname == "mlp":
                            if _torch_ok():
                                p = best_param_dict["mlp"]["params"]
                                hidden = tuple([int(p["width"])] * int(p["nlayer"]))
                                mdl = Pipeline([
                                    ("scaler", StandardScaler()),
                                    ("mdl", MLPRegressor(
                                        hidden_layer_sizes=hidden, activation="relu",
                                        alpha=float(p.get("weight_decay", 1e-5)),
                                        learning_rate_init=float(p["lr"]),
                                        batch_size=int(p["batch"]),
                                        max_iter=int(p["epochs"]),
                                        early_stopping=True,
                                        n_iter_no_change=int(p["patience"]),
                                        random_state=42))
                                ])
                            
                        mdl.fit(X_tr, y_tr)

                    pred = mdl.predict(X_va).reshape(-1)
                    rmse = _rmse(y_va, pred)
                    mae  = float(mean_absolute_error(y_va, pred))
                    r2   = float(r2_score(y_va, pred))
                    records.append({
                        "scenario": name,
                        "region": region_tag if region_tag is not None else "GLOBAL",
                        "rep": rep,
                        "fold": fold_id,
                        "model": mname,
                        "rmse": rmse,
                        "mae": mae,
                        "r2":  r2,
                    })

    # with supervision
    sup_splitter = KFold(n_splits=5, shuffle=True, random_state=42)
    _run_scenario("with_supervision", sup_splitter)

    # without supervision (grouped)
    if groups is not None:
        groups = _to_arr(groups).reshape(-1)
        if len(groups) != n:
            raise ValueError("groups length mismatch with y.")
        grp_split = GroupKFold(n_splits=5)
        _run_scenario("without_supervision", grp_split)
    else:
        print("No groups provided; skipping 'without_supervision' scenario.")

    logs_df = pd.DataFrame.from_records(records)
    logs_path   = os.path.join(save_dir, f"logs_{region_tag or 'global'}.csv")
    params_path = os.path.join(save_dir, f"best_params_{region_tag or 'global'}.json")
    logs_df.to_csv(logs_path, index=False)
    with open(params_path, "w") as f:
        json.dump(best_param_dict, f, indent=2)

    return logs_df, best_param_dict

# %% [markdown]
# ## 8)Preliminary data preprocessing

# %%
DATA_PATH = "./data/global_clean.csv"  
SAVE_DIR = "./runs_demo" 
os.makedirs(SAVE_DIR, exist_ok=True)

df = pd.read_csv(DATA_PATH)

drop_cols_hard = [
    'Unnamed: 0','ij_grid','i_grid','j_grid','x_proj','y_proj','survey_id','date','rgi_id',
    'consensus_ice_thickness','millan_ice_thickness','itslive_v','hugonnet_dhdt',
    'glacier_length','glacier_area_km2','glacier_oggm_volume',
    'glacier_min_elev','glacier_max_elev','glacier_median_elev','glacier_outline_year',
    'lin_mb_above_z','oggm_mb_above_z','thickness_uncertainty'
]
df = df.drop(columns=[c for c in drop_cols_hard if c in df.columns], errors="ignore")

TARGET_COL = "thickness"
RGI_COL    = "RGI" if "RGI" in df.columns else "region"
ID_COL     = "glacier_id" if "glacier_id" in df.columns else None

drop_cols = {TARGET_COL, RGI_COL, "lat", "lon", "year", "date"}
if ID_COL: drop_cols.add(ID_COL)
num_df = df.select_dtypes(include=[np.number])
feat_cols = [c for c in num_df.columns if c not in drop_cols]

X = df[feat_cols].astype(float).copy()
y = df[TARGET_COL].astype(float).copy()
regions = df[RGI_COL].astype(str).copy()
groups_glacier = df[ID_COL].astype(str).copy() if ID_COL else None

scaler = StandardScaler()
X_std = pd.DataFrame(scaler.fit_transform(X), columns=feat_cols, index=X.index)

print(f"Samples: {len(df)} | Features: {len(feat_cols)}")
print("Feature preview:", feat_cols[:10])
# Out:
# Samples: 284558 | Features: 18
# Feature preview: ['latitude', 'longitude', 'topo', 'topo_smoothed', 'slope', 'slope_factor', 'aspect', 'dis_from_border', 'catchment_area', 'millan_v']

# %% [markdown]
# ## 9)Model training and tuning

# %%
logs_global, best_params_global = run_one_dataset(
    X, y, X_std=None,
    groups=None,
    region_tag=None,
    n_repeats=1,
    xgb_trials=80, cat_trials=100, lgb_trials=100, mlp_trials=40,
    save_dir=SAVE_DIR
)
display(logs_global.groupby(["scenario","model"])["rmse"].agg(["mean","std"]).round(5))
# Out:
# [I 2025-09-02 11:20:20,550] A new study created in memory with name: xgb_study
# [I 2025-09-02 11:20:26,153] Trial 0 finished with value: 38.02684822580678 and parameters: {'max_depth': 9, 'eta': 0.17254716573280354, 'min_child_weight': 9.051933359925457, 'subsample': 0.8394633936788146, 'colsample_bytree': 0.6624074561769746, 'lambda': 0.000602521573620386, 'alpha': 2.231010801867921e-06}. Best is trial 0 with value: 38.02684822580678.
# [I 2025-09-02 11:20:42,807] Trial 1 finished with value: 35.50529089012883 and parameters: {'max_depth': 13, 'eta': 0.06054365855469246, 'min_child_weight': 8.788798355756501, 'subsample': 0.608233797718321, 'colsample_bytree': 0.9879639408647978, 'lambda': 1.452824663751602, 'alpha': 1.879466824163847e-05}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:20:46,302] Trial 2 finished with value: 59.37419360088611 and parameters: {'max_depth': 7, 'eta': 0.017322667470546258, 'min_child_weight': 4.346664672554915, 'subsample': 0.8099025726528951, 'colsample_bytree': 0.7727780074568463, 'lambda': 0.0028585493941961923, 'alpha': 0.004689400963537687}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:20:49,777] Trial 3 finished with value: 55.61708628159342 and parameters: {'max_depth': 7, 'eta': 0.023993242906812727, 'min_child_weight': 5.029980276230608, 'subsample': 0.7824279936868144, 'colsample_bytree': 0.9140703845572055, 'lambda': 0.0009962513222055108, 'alpha': 0.0012173252504194046}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:00,511] Trial 4 finished with value: 47.08681498934905 and parameters: {'max_depth': 11, 'eta': 0.011492999300221412, 'min_child_weight': 7.682993370915822, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'lambda': 5.5517216852447255, 'alpha': 0.622002597681916}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:23,837] Trial 5 finished with value: 35.5236158071815 and parameters: {'max_depth': 13, 'eta': 0.0249064396938244, 'min_child_weight': 2.0743932540702223, 'subsample': 0.8736932106048627, 'colsample_bytree': 0.7760609974958406, 'lambda': 0.0004075596440072873, 'alpha': 0.0009355380606452182}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:26,469] Trial 6 finished with value: 45.98274258882402 and parameters: {'max_depth': 6, 'eta': 0.15242391728466367, 'min_child_weight': 3.846579797600186, 'subsample': 0.8650089137415928, 'colsample_bytree': 0.7246844304357644, 'lambda': 0.039841905944346875, 'alpha': 0.0019066091638188462}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:29,731] Trial 7 finished with value: 40.96967948803116 and parameters: {'max_depth': 7, 'eta': 0.18258230439200238, 'min_child_weight': 9.52646105697226, 'subsample': 0.9757995766256756, 'colsample_bytree': 0.9579309401710595, 'lambda': 0.09761125443110447, 'alpha': 0.33981724150105963}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:32,501] Trial 8 finished with value: 65.16730383256963 and parameters: {'max_depth': 6, 'eta': 0.017987863473362915, 'min_child_weight': 1.4975001780159187, 'subsample': 0.7301321323053057, 'colsample_bytree': 0.7554709158757928, 'lambda': 0.002273762810253686, 'alpha': 0.09384800715909536}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:38,377] Trial 9 finished with value: 45.65825576643075 and parameters: {'max_depth': 9, 'eta': 0.023200867504756827, 'min_child_weight': 6.9696569147407335, 'subsample': 0.6563696899899051, 'colsample_bytree': 0.9208787923016158, 'lambda': 0.0002359137306347715, 'alpha': 0.8342988013047348}. Best is trial 1 with value: 35.50529089012883.
# [I 2025-09-02 11:21:56,700] Trial 10 finished with value: 35.31583371257443 and parameters: {'max_depth': 14, 'eta': 0.0712211545803935, 'min_child_weight': 11.664908218666524, 'subsample': 0.6071847502459279, 'colsample_bytree': 0.8607466203112715, 'lambda': 3.4540130684562187, 'alpha': 3.057213426609748e-06}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:22:15,220] Trial 11 finished with value: 35.344951504967064 and parameters: {'max_depth': 14, 'eta': 0.06540251149590114, 'min_child_weight': 11.972120222425657, 'subsample': 0.6034989467874442, 'colsample_bytree': 0.8663210156640422, 'lambda': 6.804061662893785, 'alpha': 2.568164392275143e-06}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:22:32,995] Trial 12 finished with value: 35.65639457277675 and parameters: {'max_depth': 14, 'eta': 0.07449186199378952, 'min_child_weight': 11.947333490135945, 'subsample': 0.601687448505531, 'colsample_bytree': 0.8700857191344269, 'lambda': 0.6220347360824077, 'alpha': 2.678643251281552e-06}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:22:45,415] Trial 13 finished with value: 35.526356682208444 and parameters: {'max_depth': 12, 'eta': 0.0855386132882483, 'min_child_weight': 11.537137310530365, 'subsample': 0.702764786891564, 'colsample_bytree': 0.8269744954538588, 'lambda': 9.115361045194264, 'alpha': 2.305866022403603e-05}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:23:04,076] Trial 14 finished with value: 35.68420345377655 and parameters: {'max_depth': 14, 'eta': 0.04405364303847517, 'min_child_weight': 10.564805872904875, 'subsample': 0.7309363326847664, 'colsample_bytree': 0.8443217789069789, 'lambda': 0.4071913062930812, 'alpha': 4.228567604409944e-05}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:23:13,718] Trial 15 finished with value: 36.104883516727796 and parameters: {'max_depth': 11, 'eta': 0.10798191180707457, 'min_child_weight': 10.512762455131895, 'subsample': 0.6513680731828184, 'colsample_bytree': 0.8818326456276585, 'lambda': 2.3421363966498467, 'alpha': 0.00011456855645022228}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:23:28,242] Trial 16 finished with value: 36.10171774685322 and parameters: {'max_depth': 13, 'eta': 0.04063228559911239, 'min_child_weight': 10.308451099887577, 'subsample': 0.9429564520037396, 'colsample_bytree': 0.7074973666184451, 'lambda': 0.1948848332235996, 'alpha': 1.1639521730508307e-06}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:23:47,432] Trial 17 finished with value: 35.383710841847815 and parameters: {'max_depth': 14, 'eta': 0.05439138164285101, 'min_child_weight': 8.01395099387243, 'subsample': 0.6021174759936104, 'colsample_bytree': 0.8171539549194355, 'lambda': 0.010719572989020662, 'alpha': 7.102897745857334e-06}. Best is trial 10 with value: 35.31583371257443.
# [I 2025-09-02 11:24:02,711] Trial 18 finished with value: 35.29764423935139 and parameters: {'max_depth': 12, 'eta': 0.11204808970811375, 'min_child_weight': 5.893983548788678, 'subsample': 0.7630911599772341, 'colsample_bytree': 0.9255513280112256, 'lambda': 2.6770116587670354, 'alpha': 0.00023290058011204797}. Best is trial 18 with value: 35.29764423935139.
# [I 2025-09-02 11:24:13,707] Trial 19 finished with value: 35.499781528046555 and parameters: {'max_depth': 11, 'eta': 0.11160578073985199, 'min_child_weight': 5.7349729119397175, 'subsample': 0.7792716766946337, 'colsample_bytree': 0.9361039842757011, 'lambda': 1.5109754889946285, 'alpha': 0.00018494403340729362}. Best is trial 18 with value: 35.29764423935139.
# [I 2025-09-02 11:24:28,980] Trial 20 finished with value: 35.80221983372085 and parameters: {'max_depth': 12, 'eta': 0.1178389624795336, 'min_child_weight': 3.25051160086166, 'subsample': 0.9183471047574293, 'colsample_bytree': 0.9881279882678704, 'lambda': 0.01994945539949846, 'alpha': 0.006216189279476732}. Best is trial 18 with value: 35.29764423935139.
# [I 2025-09-02 11:24:43,258] Trial 21 finished with value: 35.175401396182586 and parameters: {'max_depth': 12, 'eta': 0.08067369872277348, 'min_child_weight': 6.311335111075315, 'subsample': 0.691346484168823, 'colsample_bytree': 0.8725947984564898, 'lambda': 3.1009255120949994, 'alpha': 6.285868174735133e-06}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:24:57,531] Trial 22 finished with value: 35.332028614682535 and parameters: {'max_depth': 12, 'eta': 0.088585863454028, 'min_child_weight': 6.1118643167515225, 'subsample': 0.7021050863682022, 'colsample_bytree': 0.8973706653463593, 'lambda': 0.587259516889465, 'alpha': 0.00014163859519265848}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:25:05,599] Trial 23 finished with value: 40.23925014417852 and parameters: {'max_depth': 10, 'eta': 0.036260764883056386, 'min_child_weight': 7.212034427842432, 'subsample': 0.7568781744716969, 'colsample_bytree': 0.8471975688302789, 'lambda': 2.7613677276029946, 'alpha': 9.391969776850487e-06}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:25:25,256] Trial 24 finished with value: 36.30171829643854 and parameters: {'max_depth': 13, 'eta': 0.13508909565212399, 'min_child_weight': 5.331334234016763, 'subsample': 0.6818506671679664, 'colsample_bytree': 0.9496606563368476, 'lambda': 0.18975319243446923, 'alpha': 0.0003775008087116528}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:25:32,895] Trial 25 finished with value: 36.44354441963383 and parameters: {'max_depth': 10, 'eta': 0.08978606193399775, 'min_child_weight': 6.528892673111511, 'subsample': 0.7360417752687772, 'colsample_bytree': 0.8032162824981579, 'lambda': 1.0809299689057874, 'alpha': 4.8174646095716184e-05}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:25:50,620] Trial 26 finished with value: 35.24976904401874 and parameters: {'max_depth': 12, 'eta': 0.056059923161015233, 'min_child_weight': 2.8609230985698795, 'subsample': 0.63917426224293, 'colsample_bytree': 0.8981922283909242, 'lambda': 4.63956068413882, 'alpha': 0.030375651148043397}. Best is trial 21 with value: 35.175401396182586.
# [I 2025-09-02 11:26:08,140] Trial 27 finished with value: 35.136347549949726 and parameters: {'max_depth': 12, 'eta': 0.053667772306472065, 'min_child_weight': 2.2790730844023717, 'subsample': 0.6347740097312898, 'colsample_bytree': 0.9627268942570474, 'lambda': 0.2255085827804355, 'alpha': 0.03210180895955296}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:26:20,701] Trial 28 finished with value: 36.77863536397316 and parameters: {'max_depth': 11, 'eta': 0.03456276471622825, 'min_child_weight': 2.8887253763021854, 'subsample': 0.6408340019804268, 'colsample_bytree': 0.9693997538611993, 'lambda': 0.06781539762855568, 'alpha': 0.036898254883146415}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:26:27,015] Trial 29 finished with value: 39.63221940964074 and parameters: {'max_depth': 9, 'eta': 0.048496172566047026, 'min_child_weight': 1.1717962497802772, 'subsample': 0.6332386600083757, 'colsample_bytree': 0.905391076487933, 'lambda': 0.2489176986753623, 'alpha': 0.02197902602550733}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:26:35,702] Trial 30 finished with value: 38.77055312469088 and parameters: {'max_depth': 10, 'eta': 0.03338370654460342, 'min_child_weight': 2.407543761181696, 'subsample': 0.6943228428438747, 'colsample_bytree': 0.8876166797426563, 'lambda': 0.00010030222372056603, 'alpha': 0.09345519218455997}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:26:51,388] Trial 31 finished with value: 35.49378578759317 and parameters: {'max_depth': 12, 'eta': 0.05264245453735011, 'min_child_weight': 4.268583119053924, 'subsample': 0.8122622733458628, 'colsample_bytree': 0.9350848695767333, 'lambda': 4.294683048884961, 'alpha': 0.0075632668765556275}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:27:07,229] Trial 32 finished with value: 35.17264396668466 and parameters: {'max_depth': 12, 'eta': 0.064893708834153, 'min_child_weight': 4.780892100259931, 'subsample': 0.6710766255297047, 'colsample_bytree': 0.9926660711636572, 'lambda': 1.0436253734210672, 'alpha': 0.02345949214895267}. Best is trial 27 with value: 35.136347549949726.
# [I 2025-09-02 11:27:28,766] Trial 33 finished with value: 35.02228129791507 and parameters: {'max_depth': 13, 'eta': 0.05699966449389085, 'min_child_weight': 3.6312956953539053, 'subsample': 0.6316157556533275, 'colsample_bytree': 0.9840963657215707, 'lambda': 1.184839377897545, 'alpha': 0.020223361587995807}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:27:49,299] Trial 34 finished with value: 35.178746005876015 and parameters: {'max_depth': 13, 'eta': 0.06759134445982444, 'min_child_weight': 4.823824389956448, 'subsample': 0.6778163972708284, 'colsample_bytree': 0.9968936735880657, 'lambda': 1.0795420237397693, 'alpha': 0.18340399436786808}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:28:00,785] Trial 35 finished with value: 35.40134435568508 and parameters: {'max_depth': 11, 'eta': 0.07784756235865184, 'min_child_weight': 4.0944042281676065, 'subsample': 0.6344282918613073, 'colsample_bytree': 0.9711519894164812, 'lambda': 0.37459391906586226, 'alpha': 0.013625048661087729}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:28:21,049] Trial 36 finished with value: 35.1870530988311 and parameters: {'max_depth': 13, 'eta': 0.0426814277713485, 'min_child_weight': 4.851697123413159, 'subsample': 0.6639927634120478, 'colsample_bytree': 0.9851016418469026, 'lambda': 0.955689562087449, 'alpha': 0.0036273445388005903}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:28:42,672] Trial 37 finished with value: 35.09964267135325 and parameters: {'max_depth': 13, 'eta': 0.06110598875260523, 'min_child_weight': 3.5537561425141604, 'subsample': 0.7123648941690447, 'colsample_bytree': 0.9516526435926291, 'lambda': 0.09946136268903977, 'alpha': 0.07323144385026695}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:29:04,152] Trial 38 finished with value: 35.64935212492897 and parameters: {'max_depth': 13, 'eta': 0.03015385542666468, 'min_child_weight': 3.553745019469604, 'subsample': 0.6311257760749187, 'colsample_bytree': 0.9499258156843604, 'lambda': 0.07837440193153748, 'alpha': 0.06175364828256613}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:29:27,601] Trial 39 finished with value: 35.17243105680167 and parameters: {'max_depth': 13, 'eta': 0.060409659417106944, 'min_child_weight': 2.0405734736778607, 'subsample': 0.7136944550200156, 'colsample_bytree': 0.9978166324036646, 'lambda': 0.009571995578935025, 'alpha': 0.38592409088214535}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:29:50,157] Trial 40 finished with value: 35.41091235081156 and parameters: {'max_depth': 13, 'eta': 0.026931655255834897, 'min_child_weight': 2.056628210037856, 'subsample': 0.8329358604555999, 'colsample_bytree': 0.6195563704486615, 'lambda': 0.007177387778361679, 'alpha': 0.2800215379760574}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:30:15,948] Trial 41 finished with value: 35.2458399034455 and parameters: {'max_depth': 13, 'eta': 0.06164589330092962, 'min_child_weight': 1.8840332339144517, 'subsample': 0.6673911157582066, 'colsample_bytree': 0.9970060519134528, 'lambda': 0.01942523533899394, 'alpha': 0.16491105109442}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:30:44,979] Trial 42 finished with value: 35.37139405241839 and parameters: {'max_depth': 14, 'eta': 0.04716651224465069, 'min_child_weight': 2.6870724097576373, 'subsample': 0.7189971688613808, 'colsample_bytree': 0.9695113496587493, 'lambda': 0.133259045798406, 'alpha': 0.014951765464701715}. Best is trial 33 with value: 35.02228129791507.
# [I 2025-09-02 11:31:06,737] Trial 43 finished with value: 34.983678570671934 and parameters: {'max_depth': 13, 'eta': 0.06347243257178321, 'min_child_weight': 3.436562308588897, 'subsample': 0.7155444936830717, 'colsample_bytree': 0.9564229805586405, 'lambda': 0.03591280450354388, 'alpha': 0.5203674115294399}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:31:34,568] Trial 44 finished with value: 38.00604018128734 and parameters: {'max_depth': 13, 'eta': 0.011869879416161746, 'min_child_weight': 1.0472666906370498, 'subsample': 0.7427678118604039, 'colsample_bytree': 0.9532899040953572, 'lambda': 0.03946852360950913, 'alpha': 0.4646954658603296}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:32:01,613] Trial 45 finished with value: 36.29371169710115 and parameters: {'max_depth': 14, 'eta': 0.0975163162516607, 'min_child_weight': 3.3011551666254637, 'subsample': 0.7119265464609317, 'colsample_bytree': 0.9697084281993994, 'lambda': 0.003797162380239706, 'alpha': 0.07263780214570073}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:32:06,282] Trial 46 finished with value: 41.69050334995407 and parameters: {'max_depth': 8, 'eta': 0.058498863533274145, 'min_child_weight': 1.6755807407094374, 'subsample': 0.7818881526738202, 'colsample_bytree': 0.9165667970864583, 'lambda': 0.02333331369499424, 'alpha': 0.920028503232622}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:32:35,118] Trial 47 finished with value: 35.28415327149566 and parameters: {'max_depth': 14, 'eta': 0.05004909601450317, 'min_child_weight': 2.3318605890474386, 'subsample': 0.6214409213108828, 'colsample_bytree': 0.9378254444237455, 'lambda': 0.0014376499430991858, 'alpha': 0.20463737265391646}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:32:56,934] Trial 48 finished with value: 35.27885854547972 and parameters: {'max_depth': 13, 'eta': 0.03871546816634252, 'min_child_weight': 3.7829649445700806, 'subsample': 0.754308249410566, 'colsample_bytree': 0.9765801441506509, 'lambda': 0.06249677896740038, 'alpha': 0.45521857802258775}. Best is trial 43 with value: 34.983678570671934.
# [I 2025-09-02 11:33:13,433] Trial 49 finished with value: 34.93306805614448 and parameters: {'max_depth': 12, 'eta': 0.07227995976329978, 'min_child_weight': 2.952859901647898, 'subsample': 0.7139559025659283, 'colsample_bytree': 0.6815847322157986, 'lambda': 0.004810743851385012, 'alpha': 0.0023556484978626826}. Best is trial 49 with value: 34.93306805614448.
# [I 2025-09-02 11:33:24,192] Trial 50 finished with value: 35.60694050148892 and parameters: {'max_depth': 11, 'eta': 0.07569960184991999, 'min_child_weight': 3.2991900146716486, 'subsample': 0.6523951084000291, 'colsample_bytree': 0.6418532582073223, 'lambda': 0.0006263155605498848, 'alpha': 0.0021215284216663886}. Best is trial 49 with value: 34.93306805614448.
# [I 2025-09-02 11:33:42,266] Trial 51 finished with value: 34.89787968655979 and parameters: {'max_depth': 12, 'eta': 0.06834790026304963, 'min_child_weight': 1.5214020757509732, 'subsample': 0.7184352796125951, 'colsample_bytree': 0.6949538608529942, 'lambda': 0.01009328069550286, 'alpha': 0.0007445929877708684}. Best is trial 51 with value: 34.89787968655979.
# [I 2025-09-02 11:34:00,079] Trial 52 finished with value: 34.91641463665559 and parameters: {'max_depth': 12, 'eta': 0.07004000315048434, 'min_child_weight': 1.4754981318395586, 'subsample': 0.8102618325707633, 'colsample_bytree': 0.6914327739312369, 'lambda': 0.005329657879122541, 'alpha': 0.0009681023752378188}. Best is trial 51 with value: 34.89787968655979.
# [I 2025-09-02 11:34:17,916] Trial 53 finished with value: 35.41941255896452 and parameters: {'max_depth': 12, 'eta': 0.09783278421371348, 'min_child_weight': 1.405073902064961, 'subsample': 0.8093492564958205, 'colsample_bytree': 0.6982266768652331, 'lambda': 0.003851658144032596, 'alpha': 0.0008094750291105504}. Best is trial 51 with value: 34.89787968655979.
# [I 2025-09-02 11:34:29,559] Trial 54 finished with value: 35.282702283906566 and parameters: {'max_depth': 11, 'eta': 0.07022156412812162, 'min_child_weight': 2.7302447907450773, 'subsample': 0.846987330859117, 'colsample_bytree': 0.6847669308356158, 'lambda': 0.001692277605975026, 'alpha': 0.0020195897040365725}. Best is trial 51 with value: 34.89787968655979.
# [I 2025-09-02 11:34:47,397] Trial 55 finished with value: 35.167103219231635 and parameters: {'max_depth': 12, 'eta': 0.07231601111443253, 'min_child_weight': 1.4584676916420163, 'subsample': 0.8767679257799672, 'colsample_bytree': 0.7412277204220445, 'lambda': 0.006153494886955216, 'alpha': 0.0007377587842771183}. Best is trial 51 with value: 34.89787968655979.
# [I 2025-09-02 11:35:11,682] Trial 56 finished with value: 34.87003086551833 and parameters: {'max_depth': 14, 'eta': 0.08109871058792391, 'min_child_weight': 3.8751807702123284, 'subsample': 0.8012299610103607, 'colsample_bytree': 0.6606825922442388, 'lambda': 0.014180670257070179, 'alpha': 0.00042200832641581243}. Best is trial 56 with value: 34.87003086551833.
# [I 2025-09-02 11:35:34,606] Trial 57 finished with value: 35.666436477130944 and parameters: {'max_depth': 14, 'eta': 0.12304220707317043, 'min_child_weight': 4.146100511681722, 'subsample': 0.7987636431799219, 'colsample_bytree': 0.6648967151419981, 'lambda': 0.01119121710763948, 'alpha': 0.00047021835800734247}. Best is trial 56 with value: 34.87003086551833.
# [I 2025-09-02 11:35:55,695] Trial 58 finished with value: 36.26076635017397 and parameters: {'max_depth': 14, 'eta': 0.14216666734839611, 'min_child_weight': 5.452650707022015, 'subsample': 0.8317225112636925, 'colsample_bytree': 0.6035697439679856, 'lambda': 0.0030028057205884876, 'alpha': 7.417598151370088e-05}. Best is trial 56 with value: 34.87003086551833.
# [I 2025-09-02 11:36:20,175] Trial 59 finished with value: 35.53364895482322 and parameters: {'max_depth': 14, 'eta': 0.10081848193724659, 'min_child_weight': 3.0659183200478424, 'subsample': 0.772506315488163, 'colsample_bytree': 0.6656850960031785, 'lambda': 0.015406392217323563, 'alpha': 0.0012746932887369108}. Best is trial 56 with value: 34.87003086551833.
# [I 2025-09-02 11:36:32,444] Trial 60 finished with value: 35.48820293882203 and parameters: {'max_depth': 12, 'eta': 0.08545205962272806, 'min_child_weight': 8.916166963089706, 'subsample': 0.8625394807973803, 'colsample_bytree': 0.7226254377396096, 'lambda': 0.0058974463924540985, 'alpha': 0.0003016034143461801}. Best is trial 56 with value: 34.87003086551833.
# [I 2025-09-02 11:36:52,700] Trial 61 finished with value: 34.80428193165946 and parameters: {'max_depth': 13, 'eta': 0.06382668543223174, 'min_child_weight': 3.7369213055154678, 'subsample': 0.7925850455515145, 'colsample_bytree': 0.7733427341343663, 'lambda': 0.02952961574702725, 'alpha': 0.004457774011738713}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:37:12,718] Trial 62 finished with value: 35.011554230996325 and parameters: {'max_depth': 13, 'eta': 0.08041605666067603, 'min_child_weight': 3.8726213366448587, 'subsample': 0.7901547135287068, 'colsample_bytree': 0.6834690369116411, 'lambda': 0.01315706914799804, 'alpha': 0.003292980542975599}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:37:31,509] Trial 63 finished with value: 34.950789893842234 and parameters: {'max_depth': 13, 'eta': 0.08207242820787689, 'min_child_weight': 4.463890854454415, 'subsample': 0.7955063049465385, 'colsample_bytree': 0.6813941433807418, 'lambda': 0.030058529519289546, 'alpha': 0.0005722993676452793}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:37:53,208] Trial 64 finished with value: 35.274159726712874 and parameters: {'max_depth': 13, 'eta': 0.08813334373694795, 'min_child_weight': 2.520152150120695, 'subsample': 0.8181669611886646, 'colsample_bytree': 0.7608528683060919, 'lambda': 0.04120774671324185, 'alpha': 0.0005668219453992763}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:38:07,815] Trial 65 finished with value: 36.40998696620002 and parameters: {'max_depth': 12, 'eta': 0.16395355134286155, 'min_child_weight': 4.641215242240205, 'subsample': 0.7458911208029224, 'colsample_bytree': 0.6493949372706878, 'lambda': 0.028035239756974986, 'alpha': 0.00018644970363671767}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:38:31,492] Trial 66 finished with value: 34.92404930214585 and parameters: {'max_depth': 14, 'eta': 0.06731656949459958, 'min_child_weight': 4.4955347609489165, 'subsample': 0.771572743473949, 'colsample_bytree': 0.7162709082752909, 'lambda': 0.046818528899799795, 'alpha': 0.0013528069895855513}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:38:55,629] Trial 67 finished with value: 37.627995269397985 and parameters: {'max_depth': 14, 'eta': 0.19745602576641044, 'min_child_weight': 4.572806456460693, 'subsample': 0.767521555118953, 'colsample_bytree': 0.7848296363945263, 'lambda': 0.05300821451637865, 'alpha': 0.0012476567947623438}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:39:17,570] Trial 68 finished with value: 34.96915681297903 and parameters: {'max_depth': 14, 'eta': 0.07091506830967718, 'min_child_weight': 5.5363434121857225, 'subsample': 0.7955510382429596, 'colsample_bytree': 0.7130309818796825, 'lambda': 0.007985830096961109, 'alpha': 0.006796343356480914}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:39:20,306] Trial 69 finished with value: 48.16307510228166 and parameters: {'max_depth': 6, 'eta': 0.10523888446679573, 'min_child_weight': 3.03060245335665, 'subsample': 0.8199601385631295, 'colsample_bytree': 0.7396255952274474, 'lambda': 0.004676934748549005, 'alpha': 0.001507972338209595}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:39:41,746] Trial 70 finished with value: 35.37168517250756 and parameters: {'max_depth': 14, 'eta': 0.09323731733615029, 'min_child_weight': 5.2696807217631125, 'subsample': 0.8478802992193102, 'colsample_bytree': 0.6887917510572742, 'lambda': 0.015345022275088252, 'alpha': 0.0035433307670795985}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:40:03,468] Trial 71 finished with value: 34.962607065568385 and parameters: {'max_depth': 14, 'eta': 0.0691311012765069, 'min_child_weight': 5.67794692392957, 'subsample': 0.7948966035496271, 'colsample_bytree': 0.7066827975046084, 'lambda': 0.007439203084230826, 'alpha': 0.00833066560184983}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:40:27,007] Trial 72 finished with value: 35.12887263920871 and parameters: {'max_depth': 14, 'eta': 0.08207829340426942, 'min_child_weight': 4.417827152215916, 'subsample': 0.7887788511647238, 'colsample_bytree': 0.6768930360076864, 'lambda': 0.0020911913110293217, 'alpha': 0.0025924897158771873}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:40:49,167] Trial 73 finished with value: 34.916054418856696 and parameters: {'max_depth': 14, 'eta': 0.06787667989141816, 'min_child_weight': 5.14340124777377, 'subsample': 0.7752983376111432, 'colsample_bytree': 0.7029400839819216, 'lambda': 0.026308266550618374, 'alpha': 0.008645338961838693}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:41:09,141] Trial 74 finished with value: 34.87042994705181 and parameters: {'max_depth': 13, 'eta': 0.07661005237799061, 'min_child_weight': 3.9444080959110583, 'subsample': 0.758838604660234, 'colsample_bytree': 0.6464856327266605, 'lambda': 0.029735729706960132, 'alpha': 0.004831271903795819}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:41:19,725] Trial 75 finished with value: 36.089815074999386 and parameters: {'max_depth': 11, 'eta': 0.05305050598104322, 'min_child_weight': 4.045239466109853, 'subsample': 0.7574214820955992, 'colsample_bytree': 0.6365891026794244, 'lambda': 0.02025280593441658, 'alpha': 0.000956640633248228}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:41:33,442] Trial 76 finished with value: 35.43029121543739 and parameters: {'max_depth': 12, 'eta': 0.04711079243917674, 'min_child_weight': 5.10729221611292, 'subsample': 0.730508396001832, 'colsample_bytree': 0.656074695940318, 'lambda': 0.04783477323526406, 'alpha': 0.005283239228614649}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:42:04,019] Trial 77 finished with value: 35.20423808791492 and parameters: {'max_depth': 14, 'eta': 0.07613423624185252, 'min_child_weight': 1.7923518794575923, 'subsample': 0.7720788633806919, 'colsample_bytree': 0.7373057596141794, 'lambda': 0.09562164523231786, 'alpha': 0.010813815409894418}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:42:21,688] Trial 78 finished with value: 35.01113060964453 and parameters: {'max_depth': 13, 'eta': 0.06406582158808707, 'min_child_weight': 5.953130435959932, 'subsample': 0.7474740667694987, 'colsample_bytree': 0.6958855368225462, 'lambda': 0.010103446339567784, 'alpha': 0.004248688327420539}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:42:38,835] Trial 79 finished with value: 35.58012527550698 and parameters: {'max_depth': 14, 'eta': 0.05685575669904123, 'min_child_weight': 8.197283963823219, 'subsample': 0.9986137627707244, 'colsample_bytree': 0.7222120240541703, 'lambda': 0.025793379685386593, 'alpha': 0.00029772199190140057}. Best is trial 61 with value: 34.80428193165946.
# [I 2025-09-02 11:42:38,837] A new study created in memory with name: cat_study
# [I 2025-09-02 11:42:52,176] Trial 0 finished with value: 48.21532748530278 and parameters: {'depth': 7, 'learning_rate': 0.1785436060870726, 'l2_leaf_reg': 1.4071095169064511, 'subsample': 0.8394633936788146}. Best is trial 0 with value: 48.21532748530278.
# [I 2025-09-02 11:43:04,128] Trial 1 finished with value: 68.51861636812647 and parameters: {'depth': 6, 'learning_rate': 0.02864339657822303, 'l2_leaf_reg': 0.0017775399007348214, 'subsample': 0.9464704583099741}. Best is trial 0 with value: 48.21532748530278.
# [I 2025-09-02 11:43:25,858] Trial 2 finished with value: 44.36528578510123 and parameters: {'depth': 9, 'learning_rate': 0.10211806418789517, 'l2_leaf_reg': 0.0012261243785158802, 'subsample': 0.9879639408647978}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:43:57,854] Trial 3 finished with value: 51.472924355535135 and parameters: {'depth': 10, 'learning_rate': 0.03261137469244295, 'l2_leaf_reg': 0.006053891567028103, 'subsample': 0.6733618039413735}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:44:10,413] Trial 4 finished with value: 55.859710944447855 and parameters: {'depth': 7, 'learning_rate': 0.06695552617031866, 'l2_leaf_reg': 0.07207895500630218, 'subsample': 0.7164916560792167}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:44:30,952] Trial 5 finished with value: 56.92403293058524 and parameters: {'depth': 9, 'learning_rate': 0.027575529238707534, 'l2_leaf_reg': 0.018051899059704852, 'subsample': 0.7465447373174767}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:44:46,490] Trial 6 finished with value: 46.339318283361465 and parameters: {'depth': 8, 'learning_rate': 0.12195678219063029, 'l2_leaf_reg': 0.007224419004573213, 'subsample': 0.8056937753654446}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:45:01,065] Trial 7 finished with value: 63.23177691883659 and parameters: {'depth': 8, 'learning_rate': 0.022257706349811456, 'l2_leaf_reg': 0.4102689328356389, 'subsample': 0.6682096494749166}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:45:13,220] Trial 8 finished with value: 53.80778748287997 and parameters: {'depth': 6, 'learning_rate': 0.1777933581403786, 'l2_leaf_reg': 14.230243744913723, 'subsample': 0.9233589392465844}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:45:25,947] Trial 9 finished with value: 65.97118094177343 and parameters: {'depth': 7, 'learning_rate': 0.025043908574120786, 'l2_leaf_reg': 0.8768125777016167, 'subsample': 0.7760609974958406}. Best is trial 2 with value: 44.36528578510123.
# [I 2025-09-02 11:46:03,457] Trial 10 finished with value: 43.98027942793518 and parameters: {'depth': 10, 'learning_rate': 0.07242373093917133, 'l2_leaf_reg': 0.0010776090915231551, 'subsample': 0.9820366453934412}. Best is trial 10 with value: 43.98027942793518.
# [I 2025-09-02 11:46:41,242] Trial 11 finished with value: 43.70886052742698 and parameters: {'depth': 10, 'learning_rate': 0.07534546815169503, 'l2_leaf_reg': 0.0011574244282071245, 'subsample': 0.9946464529053278}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:47:17,135] Trial 12 finished with value: 46.43858457122364 and parameters: {'depth': 10, 'learning_rate': 0.05391103773183406, 'l2_leaf_reg': 0.04699477964796756, 'subsample': 0.8791164273118112}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:47:54,829] Trial 13 finished with value: 45.263584862753795 and parameters: {'depth': 10, 'learning_rate': 0.060068202795510985, 'l2_leaf_reg': 0.0013587243683536403, 'subsample': 0.987770509875096}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:48:16,612] Trial 14 finished with value: 45.10401209757837 and parameters: {'depth': 9, 'learning_rate': 0.09222646973848635, 'l2_leaf_reg': 0.005834492475420261, 'subsample': 0.9024691107672008}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:48:52,117] Trial 15 finished with value: 48.8800828024311 and parameters: {'depth': 10, 'learning_rate': 0.04228365586793147, 'l2_leaf_reg': 0.013045577140879248, 'subsample': 0.8610724800899925}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:49:14,074] Trial 16 finished with value: 45.631242011547805 and parameters: {'depth': 9, 'learning_rate': 0.08463225428243189, 'l2_leaf_reg': 0.002895002347020198, 'subsample': 0.9984066126989743}. Best is trial 11 with value: 43.70886052742698.
# [I 2025-09-02 11:49:50,910] Trial 17 finished with value: 40.13560575278529 and parameters: {'depth': 10, 'learning_rate': 0.1305866217873722, 'l2_leaf_reg': 0.024487538350238893, 'subsample': 0.9473758221087567}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:50:12,694] Trial 18 finished with value: 42.45604482992595 and parameters: {'depth': 9, 'learning_rate': 0.1309077060991277, 'l2_leaf_reg': 0.13739761316074145, 'subsample': 0.9320305561991407}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:50:32,292] Trial 19 finished with value: 42.9715126882836 and parameters: {'depth': 9, 'learning_rate': 0.1326039050681247, 'l2_leaf_reg': 0.18958262322354028, 'subsample': 0.6226952124622985}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:50:48,474] Trial 20 finished with value: 46.94958168338384 and parameters: {'depth': 8, 'learning_rate': 0.14134710305825804, 'l2_leaf_reg': 4.658142229271792, 'subsample': 0.923279895605213}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:51:07,944] Trial 21 finished with value: 42.751871010812344 and parameters: {'depth': 9, 'learning_rate': 0.13753830145558982, 'l2_leaf_reg': 0.2078431985349063, 'subsample': 0.6087667727923555}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:51:28,897] Trial 22 finished with value: 43.75590611935667 and parameters: {'depth': 9, 'learning_rate': 0.11011449848714712, 'l2_leaf_reg': 0.04625882740985098, 'subsample': 0.8224806787743902}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:51:48,384] Trial 23 finished with value: 42.111236194245464 and parameters: {'depth': 9, 'learning_rate': 0.15140666638360853, 'l2_leaf_reg': 0.19203015453792344, 'subsample': 0.6083654265933616}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:52:05,010] Trial 24 finished with value: 43.33045488236241 and parameters: {'depth': 8, 'learning_rate': 0.19628976577997548, 'l2_leaf_reg': 0.09252270219250416, 'subsample': 0.9438599500782207}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:52:25,496] Trial 25 finished with value: 41.86500795689186 and parameters: {'depth': 9, 'learning_rate': 0.15549635513999938, 'l2_leaf_reg': 0.02856455429685017, 'subsample': 0.7648556651668024}. Best is trial 17 with value: 40.13560575278529.
# [I 2025-09-02 11:52:59,483] Trial 26 finished with value: 39.63095191685414 and parameters: {'depth': 10, 'learning_rate': 0.1557685745925812, 'l2_leaf_reg': 0.023930969053755035, 'subsample': 0.7722985657276072}. Best is trial 26 with value: 39.63095191685414.
# [I 2025-09-02 11:53:33,346] Trial 27 finished with value: 39.271668070024056 and parameters: {'depth': 10, 'learning_rate': 0.1745993757586492, 'l2_leaf_reg': 0.013569303584284001, 'subsample': 0.7647234353198598}. Best is trial 27 with value: 39.271668070024056.
# [I 2025-09-02 11:54:06,187] Trial 28 finished with value: 39.35057787321091 and parameters: {'depth': 10, 'learning_rate': 0.1677412642128688, 'l2_leaf_reg': 0.014467933613404295, 'subsample': 0.717468193889083}. Best is trial 27 with value: 39.271668070024056.
# [I 2025-09-02 11:54:38,945] Trial 29 finished with value: 39.277259034974506 and parameters: {'depth': 10, 'learning_rate': 0.1759734218086495, 'l2_leaf_reg': 0.003465975291413389, 'subsample': 0.7169535728964197}. Best is trial 27 with value: 39.271668070024056.
# [I 2025-09-02 11:55:11,799] Trial 30 finished with value: 39.11682677508083 and parameters: {'depth': 10, 'learning_rate': 0.19734496216657263, 'l2_leaf_reg': 0.010574589676948848, 'subsample': 0.7166669284004076}. Best is trial 30 with value: 39.11682677508083.
# [I 2025-09-02 11:55:44,667] Trial 31 finished with value: 38.93663329754545 and parameters: {'depth': 10, 'learning_rate': 0.19659826958177046, 'l2_leaf_reg': 0.003763880062335049, 'subsample': 0.7165628175637238}. Best is trial 31 with value: 38.93663329754545.
# [I 2025-09-02 11:56:17,102] Trial 32 finished with value: 38.82310466891356 and parameters: {'depth': 10, 'learning_rate': 0.19714693474999165, 'l2_leaf_reg': 0.003786599150798623, 'subsample': 0.6969742734436635}. Best is trial 32 with value: 38.82310466891356.
# [I 2025-09-02 11:56:49,326] Trial 33 finished with value: 38.668379477926834 and parameters: {'depth': 10, 'learning_rate': 0.19428384599212753, 'l2_leaf_reg': 0.008835998102426317, 'subsample': 0.681406506863086}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:57:21,389] Trial 34 finished with value: 38.85237221263758 and parameters: {'depth': 10, 'learning_rate': 0.1943513832155445, 'l2_leaf_reg': 0.0031884140408534275, 'subsample': 0.6727684876076763}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:57:53,249] Trial 35 finished with value: 41.31236612725874 and parameters: {'depth': 10, 'learning_rate': 0.10639247676695546, 'l2_leaf_reg': 0.0023803283819834715, 'subsample': 0.663288705074667}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:58:05,479] Trial 36 finished with value: 46.84884975647044 and parameters: {'depth': 7, 'learning_rate': 0.19727407275848646, 'l2_leaf_reg': 0.005509987131956502, 'subsample': 0.6448956795147417}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:58:37,738] Trial 37 finished with value: 40.88480935603515 and parameters: {'depth': 10, 'learning_rate': 0.1156372032532497, 'l2_leaf_reg': 0.0028236001666110213, 'subsample': 0.6884225795372233}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:58:48,740] Trial 38 finished with value: 66.45158913635233 and parameters: {'depth': 6, 'learning_rate': 0.035519251544523865, 'l2_leaf_reg': 0.007712007499660699, 'subsample': 0.6942045267644693}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:59:20,034] Trial 39 finished with value: 39.47626354230612 and parameters: {'depth': 10, 'learning_rate': 0.16070665522503294, 'l2_leaf_reg': 0.004292509729796034, 'subsample': 0.6400301948355851}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 11:59:40,335] Trial 40 finished with value: 40.73163824185076 and parameters: {'depth': 9, 'learning_rate': 0.19602847151720443, 'l2_leaf_reg': 0.002196931538974759, 'subsample': 0.738936151721879}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:00:12,557] Trial 41 finished with value: 38.9671832290798 and parameters: {'depth': 10, 'learning_rate': 0.18856134726789098, 'l2_leaf_reg': 0.00823789887637241, 'subsample': 0.6865098477189522}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:00:44,840] Trial 42 finished with value: 39.35007399459333 and parameters: {'depth': 10, 'learning_rate': 0.17287987224137888, 'l2_leaf_reg': 0.008385299657623038, 'subsample': 0.6923426823192362}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:01:16,374] Trial 43 finished with value: 39.66828839712729 and parameters: {'depth': 10, 'learning_rate': 0.14936900036075626, 'l2_leaf_reg': 0.0016476088692023694, 'subsample': 0.6533107234458613}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:01:49,691] Trial 44 finished with value: 38.96334230759917 and parameters: {'depth': 10, 'learning_rate': 0.18331048005908782, 'l2_leaf_reg': 0.004472979998617997, 'subsample': 0.7367510673672035}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:02:22,882] Trial 45 finished with value: 40.745183258033464 and parameters: {'depth': 10, 'learning_rate': 0.12064419775995587, 'l2_leaf_reg': 0.0035510227022425987, 'subsample': 0.7331048071455827}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:02:57,257] Trial 46 finished with value: 42.008284780036554 and parameters: {'depth': 10, 'learning_rate': 0.09724678284217626, 'l2_leaf_reg': 0.004897832532614152, 'subsample': 0.7939275602754168}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:03:17,074] Trial 47 finished with value: 41.687438472855526 and parameters: {'depth': 9, 'learning_rate': 0.1678067243383394, 'l2_leaf_reg': 0.001042808773099284, 'subsample': 0.6722745162754262}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:03:49,682] Trial 48 finished with value: 39.80261432890886 and parameters: {'depth': 10, 'learning_rate': 0.14270718309895924, 'l2_leaf_reg': 0.001852344898623008, 'subsample': 0.7024912350590468}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:04:04,830] Trial 49 finished with value: 64.51372399443606 and parameters: {'depth': 8, 'learning_rate': 0.020421919406764105, 'l2_leaf_reg': 1.4757103187410336, 'subsample': 0.7385312430053281}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:04:16,826] Trial 50 finished with value: 47.493063008638316 and parameters: {'depth': 7, 'learning_rate': 0.17930164105511817, 'l2_leaf_reg': 0.035282370994929466, 'subsample': 0.6304909572966193}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:04:49,083] Trial 51 finished with value: 39.038065067867336 and parameters: {'depth': 10, 'learning_rate': 0.18678598571049243, 'l2_leaf_reg': 0.009293974812610914, 'subsample': 0.6815749760090005}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:05:21,671] Trial 52 finished with value: 38.94339400020841 and parameters: {'depth': 10, 'learning_rate': 0.18417041087210856, 'l2_leaf_reg': 0.01873229899176154, 'subsample': 0.7036010881837349}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:05:54,599] Trial 53 finished with value: 39.330779085820204 and parameters: {'depth': 10, 'learning_rate': 0.1611796190178052, 'l2_leaf_reg': 0.018512998847921663, 'subsample': 0.7064311179859821}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:06:28,295] Trial 54 finished with value: 39.007248479982294 and parameters: {'depth': 10, 'learning_rate': 0.17693932812949598, 'l2_leaf_reg': 0.0057233394981733654, 'subsample': 0.7523454680018972}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:07:00,107] Trial 55 finished with value: 40.39840462406402 and parameters: {'depth': 10, 'learning_rate': 0.12897237823730015, 'l2_leaf_reg': 0.003706863054820891, 'subsample': 0.6615928816588169}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:07:20,033] Trial 56 finished with value: 42.134515128987395 and parameters: {'depth': 9, 'learning_rate': 0.14706321915791673, 'l2_leaf_reg': 0.0014659118616400602, 'subsample': 0.7249143523144639}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:07:54,282] Trial 57 finished with value: 39.14024290064465 and parameters: {'depth': 10, 'learning_rate': 0.18378251038978355, 'l2_leaf_reg': 0.058445157467777856, 'subsample': 0.7888790265392689}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:08:14,486] Trial 58 finished with value: 41.686856411244925 and parameters: {'depth': 9, 'learning_rate': 0.16252020548317508, 'l2_leaf_reg': 0.017146108683537897, 'subsample': 0.7506696129320581}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:08:47,072] Trial 59 finished with value: 47.78161902131072 and parameters: {'depth': 10, 'learning_rate': 0.04671575285792195, 'l2_leaf_reg': 0.006214665439668393, 'subsample': 0.7015069362016552}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:08:58,523] Trial 60 finished with value: 58.36102355574761 and parameters: {'depth': 6, 'learning_rate': 0.08083971682317456, 'l2_leaf_reg': 0.002577993000617996, 'subsample': 0.8162677862607135}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:09:30,722] Trial 61 finished with value: 39.07265720864935 and parameters: {'depth': 10, 'learning_rate': 0.18458905566780504, 'l2_leaf_reg': 0.012217295878038235, 'subsample': 0.6817792202885308}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:10:02,850] Trial 62 finished with value: 38.897195940222105 and parameters: {'depth': 10, 'learning_rate': 0.198568227137381, 'l2_leaf_reg': 0.00774850692109821, 'subsample': 0.6760947888963147}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:10:34,396] Trial 63 finished with value: 38.90220163495281 and parameters: {'depth': 10, 'learning_rate': 0.1989313371840335, 'l2_leaf_reg': 0.004774221521363713, 'subsample': 0.6505843870274604}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:11:05,507] Trial 64 finished with value: 38.96978000252456 and parameters: {'depth': 10, 'learning_rate': 0.199594347938502, 'l2_leaf_reg': 0.006739830251224118, 'subsample': 0.6228761166008641}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:11:37,086] Trial 65 finished with value: 39.4537045209023 and parameters: {'depth': 10, 'learning_rate': 0.16566475362953417, 'l2_leaf_reg': 0.0020155921463251435, 'subsample': 0.6494985814906558}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:11:56,332] Trial 66 finished with value: 49.09608830518418 and parameters: {'depth': 9, 'learning_rate': 0.06072839737093948, 'l2_leaf_reg': 0.4122029865029353, 'subsample': 0.6700008613511439}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:12:28,055] Trial 67 finished with value: 39.638001237619825 and parameters: {'depth': 10, 'learning_rate': 0.15159499652678332, 'l2_leaf_reg': 0.021209298088727433, 'subsample': 0.6553378262148636}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:12:59,214] Trial 68 finished with value: 40.100892343227585 and parameters: {'depth': 10, 'learning_rate': 0.135920218683755, 'l2_leaf_reg': 0.010843421981646693, 'subsample': 0.6349704745232411}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:13:30,015] Trial 69 finished with value: 39.343467156183955 and parameters: {'depth': 10, 'learning_rate': 0.16851567851244859, 'l2_leaf_reg': 0.0030776112961451957, 'subsample': 0.6171555764759571}. Best is trial 33 with value: 38.668379477926834.
# [I 2025-09-02 12:13:49,831] Trial 70 finished with value: 44.593243697488234 and parameters: {'depth': 9, 'learning_rate': 0.1980307986346559, 'l2_leaf_reg': 19.732613333374914, 'subsample': 0.6785777797856359}. Best is trial 33 with value: 38.668379477926834.
# ...
# [I 2025-09-02 13:14:14,516] Trial 93 finished with value: 35.37868435407441 and parameters: {'learning_rate': 0.08548095765194794, 'num_leaves': 448, 'min_data_in_leaf': 20, 'feature_fraction': 0.8315170095129941, 'bagging_fraction': 0.6115082735365721, 'lambda_l1': 3.903977737878936e-07, 'lambda_l2': 0.994028595660674}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:14:45,267] Trial 94 finished with value: 35.538097991345914 and parameters: {'learning_rate': 0.08370455980507353, 'num_leaves': 448, 'min_data_in_leaf': 30, 'feature_fraction': 0.8170136165330449, 'bagging_fraction': 0.6002442206531946, 'lambda_l1': 7.648114947084493e-06, 'lambda_l2': 0.9197610934962241}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:15:11,843] Trial 95 finished with value: 35.51209617813348 and parameters: {'learning_rate': 0.09484469643729532, 'num_leaves': 384, 'min_data_in_leaf': 20, 'feature_fraction': 0.8373198663500903, 'bagging_fraction': 0.6653676567741813, 'lambda_l1': 3.165665719772887e-06, 'lambda_l2': 0.3074747034544172}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:15:45,488] Trial 96 finished with value: 41.475377170205526 and parameters: {'learning_rate': 0.014458974965815127, 'num_leaves': 448, 'min_data_in_leaf': 30, 'feature_fraction': 0.8591840985282189, 'bagging_fraction': 0.6091214268663059, 'lambda_l1': 1.610290491047697e-06, 'lambda_l2': 0.061526375966864055}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:16:13,970] Trial 97 finished with value: 35.388521702258075 and parameters: {'learning_rate': 0.09448093109244086, 'num_leaves': 416, 'min_data_in_leaf': 20, 'feature_fraction': 0.8450677663662085, 'bagging_fraction': 0.6374315271038352, 'lambda_l1': 6.254987344204481e-06, 'lambda_l2': 0.9942710613418677}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:16:45,215] Trial 98 finished with value: 35.897054393426075 and parameters: {'learning_rate': 0.07069688479848181, 'num_leaves': 448, 'min_data_in_leaf': 30, 'feature_fraction': 0.8805312551059691, 'bagging_fraction': 0.6261299107187966, 'lambda_l1': 1.0505702348141786e-07, 'lambda_l2': 0.3607077262091283}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:17:15,951] Trial 99 finished with value: 35.63524954967136 and parameters: {'learning_rate': 0.08761726634834767, 'num_leaves': 448, 'min_data_in_leaf': 30, 'feature_fraction': 0.8264875113179364, 'bagging_fraction': 0.6126814612395084, 'lambda_l1': 3.1523943872680486e-07, 'lambda_l2': 0.10360598173102749}. Best is trial 83 with value: 35.15479414080314.
# [I 2025-09-02 13:17:15,952] A new study created in memory with name: mlp_study
# [I 2025-09-02 13:22:23,729] Trial 0 finished with value: 82.88501827573218 and parameters: {'width': 256, 'nlayer': 2, 'dropout': 0.2598528437324805, 'lr': 0.0010502105436744284, 'weight_decay': 8.14829321010529e-05, 'batch': 4096, 'epochs': 160, 'patience': 14}. Best is trial 0 with value: 82.88501827573218.
# [I 2025-09-02 13:30:22,882] Trial 1 finished with value: 75.76111471839383 and parameters: {'width': 768, 'nlayer': 2, 'dropout': 0.1099085529881075, 'lr': 0.0005954553793888993, 'weight_decay': 0.00013157287601765647, 'batch': 8192, 'epochs': 240, 'patience': 14}. Best is trial 1 with value: 75.76111471839383.
# [I 2025-09-02 13:35:32,703] Trial 2 finished with value: 72.89229539365002 and parameters: {'width': 384, 'nlayer': 4, 'dropout': 0.13204574812188039, 'lr': 0.000161190447276092, 'weight_decay': 2.1700394405050153e-05, 'batch': 4096, 'epochs': 160, 'patience': 23}. Best is trial 2 with value: 72.89229539365002.
# [I 2025-09-02 13:44:57,480] Trial 3 finished with value: 81.95791531191108 and parameters: {'width': 384, 'nlayer': 3, 'dropout': 0.27656227050693505, 'lr': 0.00014136637008121868, 'weight_decay': 3.380273704712438e-06, 'batch': 8192, 'epochs': 280, 'patience': 19}. Best is trial 2 with value: 72.89229539365002.
# [I 2025-09-02 13:52:13,153] Trial 4 finished with value: 66.29704274359639 and parameters: {'width': 1024, 'nlayer': 4, 'dropout': 0.059614704460251716, 'lr': 0.00010218376758008094, 'weight_decay': 0.00015882027186184098, 'batch': 8192, 'epochs': 200, 'patience': 13}. Best is trial 4 with value: 66.29704274359639.
# [I 2025-09-02 13:59:00,076] Trial 5 finished with value: 74.05080073555511 and parameters: {'width': 128, 'nlayer': 4, 'dropout': 0.19126724140656393, 'lr': 0.00321623546920742, 'weight_decay': 1.881455360176988e-05, 'batch': 8192, 'epochs': 280, 'patience': 22}. Best is trial 4 with value: 66.29704274359639.
# [I 2025-09-02 14:04:10,420] Trial 6 finished with value: 65.31851370023135 and parameters: {'width': 1024, 'nlayer': 2, 'dropout': 0.15257120734941082, 'lr': 0.0034827974366176905, 'weight_decay': 4.707954411452839e-06, 'batch': 4096, 'epochs': 160, 'patience': 14}. Best is trial 6 with value: 65.31851370023135.
# [I 2025-09-02 14:13:51,242] Trial 7 finished with value: 73.1520340482409 and parameters: {'width': 128, 'nlayer': 4, 'dropout': 0.16180267257469522, 'lr': 0.002354054991673985, 'weight_decay': 0.0002621341116779162, 'batch': 16384, 'epochs': 280, 'patience': 32}. Best is trial 6 with value: 65.31851370023135.
# [I 2025-09-02 14:20:22,684] Trial 8 finished with value: 61.56980252388042 and parameters: {'width': 256, 'nlayer': 4, 'dropout': 0.09696087960622657, 'lr': 0.0007610438922351135, 'weight_decay': 7.896362593980218e-05, 'batch': 4096, 'epochs': 200, 'patience': 17}. Best is trial 8 with value: 61.56980252388042.
# [I 2025-09-02 14:25:15,625] Trial 9 finished with value: 65.47343559724342 and parameters: {'width': 384, 'nlayer': 4, 'dropout': 0.07186856720009173, 'lr': 0.00017626741740706345, 'weight_decay': 2.094200787316246e-05, 'batch': 2048, 'epochs': 160, 'patience': 28}. Best is trial 8 with value: 61.56980252388042.
# [I 2025-09-02 14:29:24,308] Trial 10 finished with value: 85.44710719701685 and parameters: {'width': 256, 'nlayer': 3, 'dropout': 0.002264195794887902, 'lr': 0.0005370961482571963, 'weight_decay': 0.0004258931791806377, 'batch': 16384, 'epochs': 120, 'patience': 10}. Best is trial 8 with value: 61.56980252388042.
# [I 2025-09-02 14:35:47,834] Trial 11 finished with value: 72.12284985167139 and parameters: {'width': 512, 'nlayer': 2, 'dropout': 0.20063774575227428, 'lr': 0.0015291389813085344, 'weight_decay': 2.429770479546349e-06, 'batch': 4096, 'epochs': 200, 'patience': 18}. Best is trial 8 with value: 61.56980252388042.
# [I 2025-09-02 14:39:48,237] Trial 12 finished with value: 54.95112299201955 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.08785980902179141, 'lr': 0.004119736665265474, 'weight_decay': 7.4082990292953626e-06, 'batch': 4096, 'epochs': 120, 'patience': 18}. Best is trial 12 with value: 54.95112299201955.
# [I 2025-09-02 14:43:39,925] Trial 13 finished with value: 79.72838712612644 and parameters: {'width': 256, 'nlayer': 3, 'dropout': 0.07428608285509668, 'lr': 0.0003150355408027347, 'weight_decay': 5.366642282113535e-05, 'batch': 4096, 'epochs': 120, 'patience': 19}. Best is trial 12 with value: 54.95112299201955.
# [I 2025-09-02 14:53:28,427] Trial 14 finished with value: 43.323741475254366 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.025620356879202305, 'lr': 0.0049627221415632595, 'weight_decay': 7.818507085621303e-06, 'batch': 2048, 'epochs': 320, 'patience': 25}. Best is trial 14 with value: 43.323741475254366.
# [I 2025-09-02 15:03:18,728] Trial 15 finished with value: 43.20753935860615 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.014114301245139073, 'lr': 0.004899420570838197, 'weight_decay': 7.34454689214986e-06, 'batch': 2048, 'epochs': 320, 'patience': 26}. Best is trial 15 with value: 43.20753935860615.
# [I 2025-09-02 15:13:05,801] Trial 16 finished with value: 42.593823335924455 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.012627758129891227, 'lr': 0.0018350250724072268, 'weight_decay': 1.0753227901759408e-06, 'batch': 2048, 'epochs': 320, 'patience': 28}. Best is trial 16 with value: 42.593823335924455.
# [I 2025-09-02 15:22:55,733] Trial 17 finished with value: 43.00050281332164 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.03039909099412616, 'lr': 0.0018876513253530897, 'weight_decay': 1.0036602552504545e-06, 'batch': 2048, 'epochs': 320, 'patience': 35}. Best is trial 16 with value: 42.593823335924455.
# [I 2025-09-02 15:32:35,870] Trial 18 finished with value: 47.19185255159939 and parameters: {'width': 512, 'nlayer': 3, 'dropout': 0.04269299841583342, 'lr': 0.0018978754545285305, 'weight_decay': 1.1397284801614678e-06, 'batch': 2048, 'epochs': 320, 'patience': 35}. Best is trial 16 with value: 42.593823335924455.
# [I 2025-09-02 15:39:52,565] Trial 19 finished with value: 46.50685631233406 and parameters: {'width': 768, 'nlayer': 3, 'dropout': 0.039108847596759456, 'lr': 0.0014174112174648644, 'weight_decay': 1.0380771211828858e-06, 'batch': 2048, 'epochs': 240, 'patience': 31}. Best is trial 16 with value: 42.593823335924455.
# [I 2025-09-02 15:48:11,022] Trial 20 finished with value: 64.50272405837012 and parameters: {'width': 1024, 'nlayer': 2, 'dropout': 0.0030867965330469097, 'lr': 0.000978284861086653, 'weight_decay': 1.7319788597517826e-06, 'batch': 2048, 'epochs': 280, 'patience': 35}. Best is trial 16 with value: 42.593823335924455.
# [I 2025-09-02 15:57:52,565] Trial 21 finished with value: 42.4400471085181 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.025615610691109236, 'lr': 0.002262151215100853, 'weight_decay': 8.634837536744625e-06, 'batch': 2048, 'epochs': 320, 'patience': 28}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:07:34,902] Trial 22 finished with value: 42.689402833715874 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.04138054491406394, 'lr': 0.002075341606078398, 'weight_decay': 1.89466229249978e-06, 'batch': 2048, 'epochs': 320, 'patience': 29}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:17:14,925] Trial 23 finished with value: 43.80657056880851 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.05825114711638721, 'lr': 0.0024901091418694696, 'weight_decay': 2.1700792365918137e-06, 'batch': 2048, 'epochs': 320, 'patience': 29}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:25:43,523] Trial 24 finished with value: 44.53314751208842 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.04593927493424898, 'lr': 0.001204087392448125, 'weight_decay': 1.247764533539054e-05, 'batch': 2048, 'epochs': 280, 'patience': 31}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:35:26,876] Trial 25 finished with value: 45.23977646239473 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.12130114669758846, 'lr': 0.002506690976271547, 'weight_decay': 3.6063546316557252e-06, 'batch': 2048, 'epochs': 320, 'patience': 28}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:43:54,816] Trial 26 finished with value: 75.2232181009795 and parameters: {'width': 1024, 'nlayer': 2, 'dropout': 0.018306862960018416, 'lr': 0.0018336681307608398, 'weight_decay': 1.8969990326720585e-06, 'batch': 16384, 'epochs': 240, 'patience': 24}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 16:52:17,118] Trial 27 finished with value: 63.002990413361694 and parameters: {'width': 128, 'nlayer': 3, 'dropout': 0.08317855730262005, 'lr': 0.0030522943879818633, 'weight_decay': 4.991263259596549e-06, 'batch': 2048, 'epochs': 280, 'patience': 27}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:01:58,458] Trial 28 finished with value: 55.18337560893799 and parameters: {'width': 512, 'nlayer': 3, 'dropout': 0.054801944923780446, 'lr': 0.00038774911417534735, 'weight_decay': 1.140615214995561e-05, 'batch': 2048, 'epochs': 320, 'patience': 30}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:10:17,186] Trial 29 finished with value: 66.17562156924487 and parameters: {'width': 768, 'nlayer': 2, 'dropout': 0.20504040208350746, 'lr': 0.0008907871631953466, 'weight_decay': 3.703010309382524e-05, 'batch': 2048, 'epochs': 280, 'patience': 33}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:20:03,843] Trial 30 finished with value: 47.89541570275985 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.22364233214143314, 'lr': 0.0012740572790618924, 'weight_decay': 1.48504472500816e-06, 'batch': 2048, 'epochs': 320, 'patience': 22}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:29:50,725] Trial 31 finished with value: 42.76385912992587 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.02876315040029507, 'lr': 0.001854140763867732, 'weight_decay': 1.024963740107074e-06, 'batch': 2048, 'epochs': 320, 'patience': 33}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:39:34,562] Trial 32 finished with value: 42.94679930095015 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.02609357693601258, 'lr': 0.0022197110569472703, 'weight_decay': 2.96749511472688e-06, 'batch': 2048, 'epochs': 320, 'patience': 32}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:49:16,506] Trial 33 finished with value: 43.915235255297375 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.0004127109212595584, 'lr': 0.0015347246203222514, 'weight_decay': 1.3135769508340344e-06, 'batch': 2048, 'epochs': 320, 'patience': 33}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 17:57:36,747] Trial 34 finished with value: 55.29495993470371 and parameters: {'width': 768, 'nlayer': 3, 'dropout': 0.29948507584980094, 'lr': 0.003003641646685413, 'weight_decay': 1.8537826190213769e-06, 'batch': 2048, 'epochs': 280, 'patience': 29}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 18:05:34,345] Trial 35 finished with value: 61.21082568739441 and parameters: {'width': 384, 'nlayer': 4, 'dropout': 0.06452637901336075, 'lr': 0.0005745035889460639, 'weight_decay': 3.952172993897277e-06, 'batch': 8192, 'epochs': 240, 'patience': 27}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 18:16:48,878] Trial 36 finished with value: 76.06980469676441 and parameters: {'width': 1024, 'nlayer': 2, 'dropout': 0.09721545110751317, 'lr': 0.0011069578606447414, 'weight_decay': 2.5778795727561373e-06, 'batch': 16384, 'epochs': 320, 'patience': 30}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 18:26:36,930] Trial 37 finished with value: 49.93416926329567 and parameters: {'width': 1024, 'nlayer': 3, 'dropout': 0.1123517619308725, 'lr': 0.003817464950279691, 'weight_decay': 5.7233837903925405e-06, 'batch': 8192, 'epochs': 280, 'patience': 24}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 18:36:11,334] Trial 38 finished with value: 60.953762751754155 and parameters: {'width': 128, 'nlayer': 3, 'dropout': 0.042105846119198084, 'lr': 0.0019787506863362856, 'weight_decay': 3.382502273109286e-05, 'batch': 2048, 'epochs': 320, 'patience': 21}. Best is trial 21 with value: 42.4400471085181.
# [I 2025-09-02 18:43:27,243] Trial 39 finished with value: 50.59997442135941 and parameters: {'width': 384, 'nlayer': 4, 'dropout': 0.02509132698601914, 'lr': 0.000751054387499789, 'weight_decay': 1.396999078576545e-06, 'batch': 2048, 'epochs': 240, 'patience': 33}. Best is trial 21 with value: 42.4400471085181.
# No groups provided; skipping 'without_supervision' scenario.
#                                 mean       std
# scenario         model
# with_supervision catboost   39.47228   0.45796
#                  lightgbm   35.75134   0.40540
#                  mlp       107.98805  12.40498
#                  xgboost    35.37767   0.49433
